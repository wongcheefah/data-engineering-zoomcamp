# %%
import pandas as pd
# Out:
# /tmp/ipykernel_97007/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %% [markdown]
# Ingest and decompress data from URL

# %%
df1 = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz', nrows=100, compression='gzip')
df1
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               100 non-null    int64
#  1   tpep_pickup_datetime   100 non-null    object
#  2   tpep_dropoff_datetime  100 non-null    object
#  3   passenger_count        100 non-null    int64
#  4   trip_distance          100 non-null    float64
#  5   RatecodeID             100 non-null    int64
#  6   store_and_fwd_flag     100 non-null    object
#  7   PULocationID           100 non-null    int64
#  8   DOLocationID           100 non-null    int64
#  9   payment_type           100 non-null    int64
#  10  fare_amount            100 non-null    float64
#  11  extra                  100 non-null    float64
#  12  mta_tax                100 non-null    float64
#  13  tip_amount             100 non-null    float64
# ...

# %% [markdown]
# Ingest and convert text to date on the fly

# %%
df2 = pd.read_csv(
    'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz',
    parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'],
    nrows=100,
    compression='gzip'
)
df2
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               100 non-null    int64
#  1   tpep_pickup_datetime   100 non-null    datetime64[ns]
#  2   tpep_dropoff_datetime  100 non-null    datetime64[ns]
#  3   passenger_count        100 non-null    int64
#  4   trip_distance          100 non-null    float64
#  5   RatecodeID             100 non-null    int64
#  6   store_and_fwd_flag     100 non-null    object
#  7   PULocationID           100 non-null    int64
#  8   DOLocationID           100 non-null    int64
#  9   payment_type           100 non-null    int64
#  10  fare_amount            100 non-null    float64
#  11  extra                  100 non-null    float64
#  12  mta_tax                100 non-null    float64
#  13  tip_amount             100 non-null    float64
# ...

# %% [markdown]
# Convert text to date after ingestion

# %%
datetime_cols = []

for col_name in df1.columns:
    if '_datetime' in col_name:
        datetime_cols.append(col_name)

# %%
datetime_cols
# Out:
# ['tpep_pickup_datetime', 'tpep_dropoff_datetime']

# %%
for column in datetime_cols:
    df1[column] = pd.to_datetime(df1[column])

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               100 non-null    int64
#  1   tpep_pickup_datetime   100 non-null    datetime64[ns]
#  2   tpep_dropoff_datetime  100 non-null    datetime64[ns]
#  3   passenger_count        100 non-null    int64
#  4   trip_distance          100 non-null    float64
#  5   RatecodeID             100 non-null    int64
#  6   store_and_fwd_flag     100 non-null    object
#  7   PULocationID           100 non-null    int64
#  8   DOLocationID           100 non-null    int64
#  9   payment_type           100 non-null    int64
#  10  fare_amount            100 non-null    float64
#  11  extra                  100 non-null    float64
#  12  mta_tax                100 non-null    float64
#  13  tip_amount             100 non-null    float64
# ...

# %% [markdown]
# The `pd.io.sql.get_schema` function gets the DDL statement for creating a table based on a dataframe.

# %%
print(pd.io.sql.get_schema(df1, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %% [markdown]
# To get the DDL statement for a specific version of SQL, create a connection engine for that specific version.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %% [markdown]
# Use the connection engine, to get the Postgres version of the DDL statement

# %%
print(pd.io.sql.get_schema(df1, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
from time import time
import pandas as pd
from sqlalchemy import create_engine, text

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

datetime_cols = ['tpep_pickup_datetime', 'tpep_dropoff_datetime']

df = pd.read_csv(
    'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz',
    parse_dates=datetime_cols,
    nrows=100,
    compression='gzip'
)

df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %% [markdown]
# Checking the database via pgcli,
# ```
# pgcli -h localhost -p 5432 -u root -d ny_taxi
# Password for root:
# Server: PostgreSQL 16.1 (Debian 16.1-1.pgdg120+1)
# Version: 4.0.1
# Home: http://pgcli.com
# root@localhost:ny_taxi> SELECT * FROM yellow_taxi_data;
# ```
# ```
# +-------+----------+----------------------+-----------------------+-----------------+---------------+------------+--------------------+--------------+--------------+--------------+-------------+-------+---------+------------+--------------+-----------------------+--------------+----------------------+
# | index | VendorID | tpep_pickup_datetime | tpep_dropoff_datetime | passenger_count | trip_distance | RatecodeID | store_and_fwd_flag | PULocationID | DOLocationID | payment_type | fare_amount | extra | mta_tax | tip_amount | tolls_amount | improvement_surcharge | total_amount | congestion_surcharge |
# |-------+----------+----------------------+-----------------------+-----------------+---------------+------------+--------------------+--------------+--------------+--------------+-------------+-------+---------+------------+--------------+-----------------------+--------------+----------------------|
# +-------+----------+----------------------+-----------------------+-----------------+---------------+------------+--------------------+--------------+--------------+--------------+-------------+-------+---------+------------+--------------+-----------------------+--------------+----------------------+
# SELECT 0
# ```

# %% [markdown]
# Using an iterator to insert the data in chunks as the entire dataset is be too large to fit in memory.

# %%
df_iter = pd.read_csv(
    'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz',
    parse_dates=datetime_cols,
    compression='gzip',
    iterator=True,
    chunksize=100000,
    low_memory=False
    )

# %%
chunk = 1

while (df := next(df_iter, None)) is not None:
    t_start = time()

    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    
    t_end = time()
    
    print(f'Chunk no. {chunk:2d}:  {len(df):>7,d} records inserted in {t_end - t_start:.2f} seconds.')
    
    chunk += 1
# Out:
# Chunk no.  1:  100,000 records inserted in 14.40 seconds.
# Chunk no.  2:  100,000 records inserted in 15.25 seconds.
# Chunk no.  3:  100,000 records inserted in 15.74 seconds.
# Chunk no.  4:  100,000 records inserted in 15.68 seconds.
# Chunk no.  5:  100,000 records inserted in 16.19 seconds.
# Chunk no.  6:  100,000 records inserted in 16.40 seconds.
# Chunk no.  7:  100,000 records inserted in 17.01 seconds.
# Chunk no.  8:  100,000 records inserted in 18.21 seconds.
# Chunk no.  9:  100,000 records inserted in 19.01 seconds.
# Chunk no. 10:  100,000 records inserted in 22.26 seconds.
# Chunk no. 11:  100,000 records inserted in 23.28 seconds.
# Chunk no. 12:  100,000 records inserted in 20.92 seconds.
# Chunk no. 13:  100,000 records inserted in 21.91 seconds.
# Chunk no. 14:   69,765 records inserted in 11.71 seconds.

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT count(1) FROM yellow_taxi_data")).fetchall()
    print()
    print(f'Total rows: {result[0][0]}')
# Out:
# Total rows: 1369765

# %% [markdown]
# ```
# pgcli -h localhost -p 5432 -u root -d
# Password for root:
# Server: PostgreSQL 16.1 (Debian 16.1-1
# Version: 4.0.1
# Home: http://pgcli.com
# root@localhost:ny_taxi> \dt
# +--------+------------------+-------+-------+
# | Schema | Name             | Type  | Owner |
# |--------+------------------+-------+-------|
# | public | yellow_taxi_data | table | root  |
# +--------+------------------+-------+-------+
# SELECT 1
# Time: 0.013s
# root@localhost:ny_taxi> \d yellow_taxi_data;
# +-----------------------+-----------------------------+-----------+
# | Column                | Type                        | Modifiers |
# |-----------------------+-----------------------------+-----------|
# | index                 | bigint                      |           |
# | VendorID              | bigint                      |           |
# | tpep_pickup_datetime  | timestamp without time zone |           |
# | tpep_dropoff_datetime | timestamp without time zone |           |
# | passenger_count       | bigint                      |           |
# | trip_distance         | double precision            |           |
# | RatecodeID            | bigint                      |           |
# | store_and_fwd_flag    | text                        |           |
# | PULocationID          | bigint                      |           |
# | DOLocationID          | bigint                      |           |
# | payment_type          | bigint                      |           |
# | fare_amount           | double precision            |           |
# | extra                 | double precision            |           |
# | mta_tax               | double precision            |           |
# | tip_amount            | double precision            |           |
# | tolls_amount          | double precision            |           |
# | improvement_surcharge | double precision            |           |
# | total_amount          | double precision            |           |
# | congestion_surcharge  | double precision            |           |
# +-----------------------+-----------------------------+-----------+
# Indexes:
#     "ix_yellow_taxi_data_index" btree (index)
#
# Time: 0.013s
# ```

# %% [markdown]
# Using sqalchemy instead of pgcli to connect to the database

# %%
from sqlalchemy import text

query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND
  schemaname != 'information_schema'; 
"""


with engine.connect() as conn:
    result = conn.execute(text(query))
    columns = result.keys()
    data = result.fetchall()
    
df = pd.DataFrame(data, columns=columns)
df
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi_data       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %% [markdown]
# Simpler way, using the `pd.read_sql_query` function

# %%
pd.read_sql_query(text(query), engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi_data       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %% [markdown]
# Some queries on the data

# %% [markdown]
# ```
# root@localhost:ny_taxi> SELECT max(tpep_pickup_datetime), min(tpep_pickup_datetime), max(total_amount) FROM yellow_taxi_data;
# +---------------------+---------------------+---------+
# | max                 | min                 | max     |
# |---------------------+---------------------+---------|
# | 2021-02-22 16:52:16 | 2008-12-31 23:05:14 | 7661.28 |
# +---------------------+---------------------+---------+
# SELECT 1
# Time: 0.194s
# ```

# %%
query = """
SELECT max(tpep_pickup_datetime), min(tpep_pickup_datetime), max(total_amount)
FROM yellow_taxi_data;
"""

pd.read_sql_query(text(query), engine)
# Out:
#                   max                 min      max
# 0 2021-02-22 16:52:16 2008-12-31 23:05:14  7661.28

# %%
query = """
SELECT max(total_amount)
FROM yellow_taxi_data;
"""

pd.read_sql_query(text(query), engine)
# Out:
#        max
# 0  7661.28
